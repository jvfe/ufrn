# %% [raw]
# ---
# lang: pt
# format:
#   revealjs:
#     theme: night
#     slide-number: true
#     footer: "Workshop PPg-Bioinfo 2023"
#     preview-links: true
#     chalkboard: true
#     multiplex: true # audience can follow along w/ mobile devices
#     transition: slide # slide # none | fade | convex | concave | zoom
#     fragments: true
#     logo: https://dalmolingroup.imd.ufrn.br/wp-content/themes/wpeducon-dalmolin/images/logo.png
# ---

# %% [markdown]
# ## Diferenças funcionais na microbiota intestinal de pacientes com TDM {.smaller .center}
#
# **05 de Dezembro de 2023**
#
# João Vitor Cavalcante
#
#
# ```{css}
# .center h2 {
#   text-align: center;
# }
#
# # Antes, um breve interlúdio...
#
# ## Minha jornada até agora {.smaller}
#
# - TCC - desenvolvimento de ferramentas para metagenômica
#   - MEDUSA - A Pipeline for Sensitive Taxonomic Classification and Flexible Functional Annotation of Metagenomic Shotgun Sequences
#
# ::: {.r-stack}
# ![](https://github.com/dalmolingroup/euryale/raw/main/assets/euryale_logo.png){.fragment width=400}
#
# ![](https://github.com/dalmolingroup/euryale/raw/main/assets/euryale_workflow.drawio.png){.fragment}
#
# ![](https://i.imgur.com/xtlpjbZ.png){.fragment}
#
# #### Veja mais no nosso pôster! {.fragment style="color: #e7ad52;"}
# :::
#
# ---
#
# ::: {style="text-align: center; display: grid; place-items: center;"}
# ![](https://i.imgur.com/hJMr1H4.png)
# :::
#
# :::: {.r-stack}
# - Sustentabilidade de software em metagenômica
#   - Reprodutibilidade
#   - Gerenciadores de workflow
#   - O ecossistema computacional de Metatranscriptômica e integração de dados de microbioma
#
# ![](https://i.imgur.com/cVJ2lBg.png){.fragment}
# ::::
#
#
# # Diferenças funcionais na microbiota intestinal de pacientes com TDM
#
# ## Introduction {.smaller}
#
# :::: {.columns}
#
# ::: {.column width="45%"}
# - "Inflammation is now considered one of the primary pathologies that lead to depression."
#
# - "The main process when suppressing inflammation is the activation of the immune response, in particular, the production of cytokines. This affects the levels of neuro-compounds, which in turn leads to the development of MDD. "
# :::
#
# ::: {.column width="55%"}
# ![Cryan et al, 2019](https://i.imgur.com/u4cLvJe.png)
# :::
#
# ::::
#
# ## Introduction {.smaller}
#
# :::: {.columns}
#
# ::: {.column width="45%"}
# - "GM also produces microbial compounds that mediate crosstalk with the immune system of the host and play an important role in the GBA"
#
# - "In this work, we used whole metagenome sequencing analysis, which gave us an opportunity to profile functional representations and metabolic pathways in the bacterial community."
# :::
#
# ::: {.column width="55%"}
# ![McGuiness et al, 2022](https://i.imgur.com/Xvk3Ysf.png)
# :::
#
# ::::
#
# ---
# ::: {style="text-align: center; display: grid !important; place-items: center !important;"}
#
# ## Diferenças funcionais na microbiota intestinal de pacientes com TDM
#
# **05 de Dezembro de 2023**
#
# João Vitor Cavalcante
#
# :::
